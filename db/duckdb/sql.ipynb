# %%
# !pip install pandas jupysql duckdb-engine
import duckdb
import pandas as pd
# Import jupysql Jupyter extension to create SQL cells
# %load_ext sql
# %reload_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False
# %sql duckdb:///db.duckdb_old
# Out:
# Requirement already satisfied: pandas in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (2.0.2)
# Requirement already satisfied: jupysql in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (0.7.8)
# Requirement already satisfied: duckdb-engine in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (0.7.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: prettytable in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from jupysql) (3.7.0)
# Requirement already satisfied: ipython in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from jupysql) (8.14.0)
# Requirement already satisfied: sqlalchemy in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from jupysql) (1.4.48)
# Requirement already satisfied: sqlparse in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from jupysql) (0.4.3)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from jupysql) (0.2.0)
# Requirement already satisfied: sqlglot in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from jupysql) (15.0.0)
# Requirement already satisfied: jinja2 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from jupysql) (3.1.2)
# Requirement already satisfied: ploomber-core>=0.2.7 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from jupysql) (0.2.11)
# Requirement already satisfied: psutil in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from jupysql) (5.9.5)
# Requirement already satisfied: duckdb>=0.4.0 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from duckdb-engine) (0.7.1)
# Requirement already satisfied: click in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from ploomber-core>=0.2.7->jupysql) (8.1.3)
# Requirement already satisfied: pyyaml in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from ploomber-core>=0.2.7->jupysql) (6.0)
# Requirement already satisfied: posthog in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from ploomber-core>=0.2.7->jupysql) (3.0.1)
# Requirement already satisfied: six>=1.5 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: backcall in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from ipython->jupysql) (0.2.0)
# Requirement already satisfied: decorator in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from ipython->jupysql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from ipython->jupysql) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from ipython->jupysql) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from ipython->jupysql) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from ipython->jupysql) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from ipython->jupysql) (2.15.1)
# Requirement already satisfied: stack-data in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from ipython->jupysql) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from ipython->jupysql) (5.9.0)
# Requirement already satisfied: pexpect>4.3 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from ipython->jupysql) (4.8.0)
# Requirement already satisfied: appnope in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from ipython->jupysql) (0.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from jinja2->jupysql) (2.1.2)
# Requirement already satisfied: wcwidth in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from prettytable->jupysql) (0.2.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from jedi>=0.16->ipython->jupysql) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from pexpect>4.3->ipython->jupysql) (0.7.0)
# Requirement already satisfied: requests<3.0,>=2.7 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (2.30.0)
# Requirement already satisfied: monotonic>=1.5 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from stack-data->ipython->jupysql) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from stack-data->ipython->jupysql) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from stack-data->ipython->jupysql) (0.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kchauhan/repos/cinemattr-db/db/env/lib/python3.11/site-packages (from requests<3.0,>=2.7->posthog->ploomber-core>=0.2.7->jupysql) (2023.5.7)
#
# [notice] A new release of pip available: 22.3 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql select count(*) from wiki_plots_final
# Out:
#    count_star()
# 0         15346

# %%
# %sql select * FROM imdb_movies m  LEFT JOIN wiki_plots_clean ON m.imdb_title_id = wiki_plots_clean.imdb_title_id WHERE m.ratingCount>10000 ORDER BY wiki_plots_clean.imdb_title_id;
# Out:
#      imdb_title_id                                    title  year certificate
# 0        tt0454945                            She's the Man  2006       PG-13  \
# 1        tt1531924  The Disappearance of Eleanor Rigby: Him  2013           R
# 2        tt0105112                            Patriot Games  1992           R
# 3        tt0104070                        Death Becomes Her  1992       PG-13
# 4       tt14209916                             Cocaine Bear  2023           R
# ...            ...                                      ...   ...         ...
# 8539     tt8097030                              Turning Red  2022          PG
# 8540    tt13352968             Good Luck to You, Leo Grande  2022           R
# 8541     tt1235522                              Broken City  2013           R
# 8542     tt1931602                          Very Good Girls  2013           R
# 8543    tt19623240         Winnie the Pooh: Blood and Honey  2023         18A
#
#                              genre  runtime
# 0           Comedy, Romance, Sport  105 min  \
# 1                   Drama, Romance   89 min
# 2                 Action, Thriller  117 min
# 3          Comedy, Fantasy, Horror  104 min
# 4                 Comedy, Thriller   95 min
# ...                            ...      ...
# 8539  Animation, Adventure, Comedy  100 min
# 8540                 Comedy, Drama   97 min
# 8541          Action, Crime, Drama  109 min
# 8542                Drama, Romance   91 min
# 8543                        Horror   84 min
#
#                                             description IMDb_rating MetaScore
# 0     When her brother decides to ditch for a couple...       6.300    45.000  \
# 1     Told from the male perspective, the story of a...       6.800    63.000
# 2     When CIA analyst Jack Ryan interferes with an ...       6.800    64.000
# 3     When a fading actress learns of an immortality...       6.600    56.000
# 4     An oddball group of cops, criminals, tourists ...       6.000    54.000
# ...                                                 ...         ...       ...
# 8539  A 13-year-old girl named Meilin turns into a g...       7.000    83.000
# 8540  Nancy Stokes, a retired school teacher, is yea...       7.200    78.000
# 8541  In a city rife with injustice, ex-cop Billy Ta...       6.100    49.000
# 8542  Two New York City girls make a pact to lose th...       5.900    35.000
# 8543  After Christopher Robin abandons them for coll...       3.000    16.000
#
#       ratingCount              directors
# 0          165192           Andy Fickman  \
# 1           10066             Ned Benson
# 2          115544          Phillip Noyce
# 3          123511        Robert Zemeckis
# 4           64554        Elizabeth Banks
# ...           ...                    ...
# 8539       132110              Domee Shi
# 8540        28357            Sophie Hyde
# 8541        81879           Allen Hughes
# 8542        15963            Naomi Foner
# 8543        15987  Rhys Frake-Waterfield
#
#                                                   stars title summary
# 0     Amanda Bynes,Laura Ramsey,Channing Tatum,Vinni...  None    None  \
# 1     James McAvoy,Jessica Chastain,Nina Arianda,Vio...  None    None
# 2     Harrison Ford,Sean Bean,Anne Archer,Patrick Be...  None    None
# 3     Meryl Streep,Bruce Willis,Goldie Hawn,Isabella...  None    None
# 4     Keri Russell,Alden Ehrenreich,O'Shea Jackson J...  None    None
# ...                                                 ...   ...     ...
# 8539      Rosalie Chiang,Sandra Oh,Ava Morse,Hyein Park  None    None
# 8540  Emma Thompson,Daryl McCormack,Isabella Laughla...  None    None
# 8541  Mark Wahlberg,Russell Crowe,Catherine Zeta-Jon...  None    None
# 8542  Dakota Fanning,Elizabeth Olsen,Sterling Jones,...  None    None
# 8543  Nikolai Leon,Maria Taylor,Craig David Dowsett,...  None    None
#
#      imdb_title_id  plot
# 0             None  None
# 1             None  None
# 2             None  None
# 3             None  None
# 4             None  None
# ...            ...   ...
# 8539          None  None
# 8540          None  None
# 8541          None  None
# 8542          None  None
# 8543          None  None
#
# [8544 rows x 16 columns]

# %%
# %sql select * from wiki_plots where title like '%Broken City%'
# Out:
#          title                                            summary
# 0  Broken City  {{Short description|2013 American thriller fil...  \
#
#                                                 plot
# 0  \n[[New York Police Department|NYPD]] police o...  \
#
#                                       external_links
# 0  \n* {{Official website|http://www.brokencitymo...
